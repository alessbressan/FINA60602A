# %% [markdown]
# # 1. Import Packages

# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize

from matplotlib import pyplot as plt

from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# # 2. Data

# %%
# load Fama French Factor Data
factors_df = pd.read_csv(str(Path().absolute()) + "/data/F-F_Research_Data_Factors.CSV", index_col = 0) 
rf = factors_df.loc[:, "RF"]
rf.index = pd.to_datetime(rf.index, format = "%Y%m")

# load 3 dataframes (returns, nb industries, avg firm size)
df = pd.read_csv(str(Path().absolute()) + "/data/10_industry_Portfolios.CSV")

# split these dataframes
df_list = np.split(df, df[df.isnull().all(1)].index, axis = 0) 

# clean data and convert date column to index
for i in range(len(df_list)):
    df_list[i] = pd.DataFrame(df_list[i])  
    df_list[i] = df_list[i].dropna()  
    df_list[i].loc[:, "Date"] = df_list[i].loc[:, "Date"].astype("int")  
    df_list[i] = df_list[i].set_index("Date")  
    df_list[i].index = pd.to_datetime(df_list[i].index, format = "%Y%m")

# create a dataframe of excess returns, nb of industries and avg sizes
df = df_list[0] / 100
nb_industries = df_list[1]
avg_size = df_list[2]
# Out:
# /var/folders/cb/4hmkv_ks12v6rtbh4ht9tzbr0000gp/T/ipykernel_76117/2364972390.py:16: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_list[i].loc[:, "Date"] = df_list[i].loc[:, "Date"].astype("int")
# /var/folders/cb/4hmkv_ks12v6rtbh4ht9tzbr0000gp/T/ipykernel_76117/2364972390.py:16: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_list[i].loc[:, "Date"] = df_list[i].loc[:, "Date"].astype("int")
# /var/folders/cb/4hmkv_ks12v6rtbh4ht9tzbr0000gp/T/ipykernel_76117/2364972390.py:16: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_list[i].loc[:, "Date"] = df_list[i].loc[:, "Date"].astype("int")

# %% [markdown]
# # 3. Portfolio Construction Functions

# %%
def neg_sharpe_ratio(w: np.array, sigma: np.array, mean: np.array, rf: float):
    """
    computes sharpe ratio of portfolio
    :param w: weights of each asset in portfolio (no risk free-asset)
    :param sigma: variance-covariance matrix of portfolio assets (no risk-free asset)
    :param mean: average excess returns of assets (no risk-free asset)
    :param rf: risk-free rate
    :return: sharpe of portfolio
    """

    return -1 * (w @ (mean - rf)) / np.sqrt(w @ sigma @ w)

# %%
def max_sharpe(df, rf, long_only = False):
    """
    description
    """
    sigma = df.cov()
    mu = df.mean(axis = 0)
    
    if long_only:
        
        # constraints and bounds on optimization
        cons = ({"type": "eq", "fun": lambda x: np.sum(x) - 1})  # weights must sum to 1
        bounds = []
        for i in range(len(mu)):
            bounds.append((0, None))

        bounds = tuple(bounds)
        
        # initial weights
        init_w = np.full(shape=len(mu), fill_value=1 / len(mu))
        
        # optimization procedure
        w = minimize(neg_sharpe_ratio, init_w, 
                              (sigma, mu, rf), 
                              constraints=cons, 
                              bounds=bounds, 
                              method="SLSQP").x
        
    else:
        
        inv_sigma = np.linalg.inv(sigma)
        ones = np.ones(len(mu))
        
        B = mu.T @ inv_sigma @ ones
        A = ones.T @ inv_sigma @ ones

        w = inv_sigma @ (mu - rf) / (B - A * rf) 
    
    return w
    

def inv_var(df):
    """
    description
    """
    
    w = (1 / df.var(axis = 0)) / sum(1 / df.var(axis = 0))
    return w


def inv_vol(df):
    """
    description
    """
    
    w = (1 / df.std(axis = 0)) / sum(1 / df.std(axis = 0))
    return w


def equal_weight(df):
    """
    description
    """
    
    return np.full(len(df.columns), fill_value = 1 / len(df.columns))


def mkt_weight(avg_size, nb_industries):
    """
    description
    """
    
    mkt_weights = avg_size * nb_industries
    mkt_weights = mkt_weights / mkt_weights.sum()
    
    return mkt_weights


def min_var(df):
    """
    description
    """
    
    sigma = df.cov()
    inv_sigma = np.linalg.inv(sigma)
    ones = np.ones(len(df.columns))
    
    w = inv_sigma @ ones / (ones.T @ inv_sigma @ ones)
    
    return w

# %%
lookback = 59

backtest = pd.DataFrame(index = df.index, columns = ["max_sharpe", "max_sharpe_long_only", "inv_var", "inv_vol", "equal_weight", "mkt_weight", "min_var"])

for i in tqdm(range(59, df.shape[0]-1)):
    
    start = df.index[i - lookback]
    end = df.index[i]
    current = df.index[i+1]
    
    backtest.loc[current, "max_sharpe"] = df.loc[current, :] @ max_sharpe(df.loc[start:end,:], rf = rf.loc[end], long_only = False)
    backtest.loc[current, "max_sharpe_long_only"] = df.loc[current, :] @ max_sharpe(df.loc[start:end,:], rf = rf.loc[end], long_only = True)
    backtest.loc[current, "inv_vol"] = df.loc[current, :] @ inv_vol(df.loc[start:end,:])
    backtest.loc[current, "inv_var"] = df.loc[current, :] @ inv_var(df.loc[start:end,:])
    backtest.loc[current, "equal_weight"] = df.loc[current, :] @ equal_weight(df.loc[start:end,:])
    backtest.loc[current, "mkt_weight"] = df.loc[current, :] @ mkt_weight(avg_size.loc[end,:], nb_industries.loc[end,:])
    backtest.loc[current, "min_var"] = df.loc[current, :] @ min_var(df.loc[start:end,:])
    
    if i >= df.shape[0] - 5:
        print(max_sharpe(df.loc[start:end,:], rf = rf.loc[end], long_only = False))
# Out:
# 100%|███████████████████████████████████████| 1122/1122 [00:15<00:00, 73.49it/s]
# [ 0.91783469 -0.03077827 -0.60075676 -0.03950129 -0.04516382  0.2113004
#   0.31779137  0.29320067  0.14424654 -0.16817354]
# [ 0.9243776  -0.03356915 -0.61362578 -0.03939829 -0.04575948  0.20381678
#   0.31973755  0.30166036  0.13634829 -0.15358789]
# [ 0.91956514 -0.03341951 -0.64189106 -0.04319995 -0.0461048   0.21121636
#   0.31585742  0.30483552  0.13947239 -0.12633153]
# [ 0.91973273 -0.03462086 -0.64296513 -0.04583403 -0.0388299   0.207183
#   0.30400789  0.31431182  0.12983312 -0.11281864]

# %%
# the first 5 years are NA and must be dropped
backtest = backtest.dropna()

# %%
rf
# Out:
# Date
# 1926-07-01    0.22
# 1926-08-01    0.25
# 1926-09-01    0.23
# 1926-10-01    0.32
# 1926-11-01    0.31
#               ...
# 2024-08-01    0.48
# 2024-09-01    0.40
# 2024-10-01    0.39
# 2024-11-01    0.40
# 2024-12-01    0.37
# Name: RF, Length: 1182, dtype: float64

# %%
backtest.sub(rf, axis = 0)
# Out:
#            max_sharpe max_sharpe_long_only   inv_var   inv_vol equal_weight  \
# Date
# 1926-07-01        NaN                  NaN       NaN       NaN          NaN
# 1926-08-01        NaN                  NaN       NaN       NaN          NaN
# 1926-09-01        NaN                  NaN       NaN       NaN          NaN
# 1926-10-01        NaN                  NaN       NaN       NaN          NaN
# 1926-11-01        NaN                  NaN       NaN       NaN          NaN
# ...               ...                  ...       ...       ...          ...
# 2024-08-01  -0.419593              -0.5316 -0.449507  -0.45526     -0.46425
# 2024-09-01  -0.387523              -0.2576 -0.377137 -0.374073     -0.36865
# 2024-10-01  -0.399441              -0.4214 -0.401036 -0.400126     -0.40015
# 2024-11-01  -0.397655              -0.1032 -0.343505 -0.333104     -0.31588
# 2024-12-01  -0.408483                -0.26 -0.421729 -0.417925     -0.40944
#
#            mkt_weight   min_var
# Date
# 1926-07-01        NaN       NaN
# 1926-08-01        NaN       NaN
# 1926-09-01        NaN       NaN
# 1926-10-01        NaN       NaN
# 1926-11-01        NaN       NaN
# ...               ...       ...
# 2024-08-01  -0.459063 -0.419547
# 2024-09-01  -0.378221 -0.389494
# 2024-10-01  -0.395893 -0.399608
# 2024-11-01  -0.331446  -0.39846
# 2024-12-01  -0.398304 -0.406983
#
# [1182 rows x 7 columns]

# %%
print("ALL TIME")
print(np.sqrt(12) * backtest.sub(rf/100, axis = 0).mean(axis = 0) / backtest.std(axis = 0))
# print(np.sqrt(12) * backtest.mean(axis = 0))
print("1990+")
print(np.sqrt(12) * (backtest.sub(rf/100, axis = 0).loc["1990-01":"2024-12"]).mean(axis = 0) / backtest.loc["1990-01":"2024-12"].std(axis = 0))
# print(np.sqrt(12) * backtest.loc["1990-01":"2024-12"].mean(axis = 0))
print("2000+")
print(np.sqrt(12) * (backtest.sub(rf/100, axis = 0).loc["2000-01":"2024-12"]).mean(axis = 0) / backtest.loc["2000-01":"2024-12"].std(axis = 0))
# print(np.sqrt(12) * backtest.loc["2000-01":"2024-12"].mean(axis = 0))
# Out:
# ALL TIME
# max_sharpe             -0.082198
# max_sharpe_long_only    0.276670
# inv_var                 0.528054
# inv_vol                 0.520076
# equal_weight            0.510327
# mkt_weight              0.473676
# min_var                 0.471408
# dtype: float64
# 1990+
# max_sharpe             -0.144183
# max_sharpe_long_only    0.284941
# inv_var                 0.637527
# inv_vol                 0.630683
# equal_weight            0.618429
# mkt_weight              0.580897
# min_var                 0.494748
# dtype: float64
# 2000+
# max_sharpe             -0.177561
# max_sharpe_long_only    0.054238
# inv_var                 0.563938
# inv_vol                 0.546875
# equal_weight            0.525008
# mkt_weight              0.466429
# min_var                 0.412698
# dtype: float64

# %%
# plot monthly returns series
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8))

backtest.plot(ax=axes[0])
axes[0].set_title('Monthly Returns (All Strategies)')

backtest.drop('max_sharpe', axis=1).plot(ax=axes[1])
axes[1].set_title('Monthly Returns (Excluding Unconstrained Max Sharpe)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Should also do Jensen's Alpha
